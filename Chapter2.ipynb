# %% [markdown]
# <a href="https://colab.research.google.com/github/uaeandrei/ColabML/blob/main/Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://data.cdc.gov/api/views/55yu-xksw/rows.csv?accessType=DOWNLOAD'
heart_df = pd.read_csv(url, index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr      LocationDesc GeographicLevel DataSource  \
# Year
# 2020           AK            Denali          County       NVSS
# 2020           CA        California           State       NVSS
# 2020           CO       Park County          County       NVSS
# 2020           FL     Walton County          County       NVSS
# 2020           GA  Whitfield County          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2020  Cardiovascular Diseases  Heart Disease Mortality       348.8
# 2020  Cardiovascular Diseases  Heart Disease Mortality       230.1
# 2020  Cardiovascular Diseases  Heart Disease Mortality       135.9
# 2020  Cardiovascular Diseases  Heart Disease Mortality       126.5
# 2020  Cardiovascular Diseases  Heart Disease Mortality       155.1
#
#              Data_Value_Unit  \
# Year
# 2020  per 100,000 population
# 2020  per 100,000 population
# 2020  per 100,000 population
# 2020  per 100,000 population
# 2020  per 100,000 population
#
#                                         Data_Value_Type  \
# Year
# 2020  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2020                  Age-adjusted, 3-year Average Rate
# 2020  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2020  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2020  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#      Data_Value_Footnote_Symbol Data_Value_Footnote StratificationCategory1  \
# Year
# 2020                        NaN                 NaN                     Sex
# 2020                        NaN                 NaN                     Sex
# 2020                        NaN                 NaN                     Sex
# 2020                        NaN                 NaN                     Sex
# 2020                        NaN                 NaN                     Sex
#
#      Stratification1 StratificationCategory2     Stratification2 TopicID  \
# Year
# 2020            Male          Race/Ethnicity               White      T2
# 2020            Male          Race/Ethnicity  More than one race      T2
# 2020          Female          Race/Ethnicity               White      T2
# 2020          Female          Race/Ethnicity               Asian      T2
# 2020          Female          Race/Ethnicity            Hispanic      T2
#
#       LocationID      Y_lat       X_lon                      Georeference
# Year
# 2020        2068  63.678820 -149.960801  POINT (-149.9608012 63.67881971)
# 2020           6  37.241400 -119.601000          POINT (-119.601 37.2414)
# 2020        8093  39.115616 -105.708698  POINT (-105.7086982 39.11561621)
# 2020       12131  30.655966  -86.157457  POINT (-86.15745736 30.65596581)
# 2020       13313  34.803854  -84.962112  POINT (-84.96211184 34.80385386)

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78792 entries, 2020 to 2020
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                78792 non-null  object
#  1   LocationDesc                78792 non-null  object
#  2   GeographicLevel             78792 non-null  object
#  3   DataSource                  78792 non-null  object
#  4   Class                       78792 non-null  object
#  5   Topic                       78792 non-null  object
#  6   Data_Value                  34430 non-null  float64
#  7   Data_Value_Unit             78792 non-null  object
#  8   Data_Value_Type             78792 non-null  object
#  9   Data_Value_Footnote_Symbol  44362 non-null  object
#  10  Data_Value_Footnote         44362 non-null  object
#  11  StratificationCategory1     78792 non-null  object
#  12  Stratification1             78792 non-null  object
#  13  StratificationCategory2     78792 non-null  object
#  14  Stratification2             78792 non-null  object
#  15  TopicID                     78792 non-null  object
#  16  LocationID                  78792 non-null  int64
#  17  Y_lat                       78768 non-null  float64
#  18  X_lon                       78768 non-null  float64
#  19  Georeference                78768 non-null  object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 12.6+ MB

# %%
from os import read
heart_df = pd.read_csv('/content/heard.csv')
engine="python"
heart_df.head()
# Out:
#    Year LocationAbbr           LocationDesc GeographicLevel DataSource  \
# 0  2020           AS  American Samoa County          County       NVSS
# 1  2020           ND           North Dakota           State       NVSS
# 2  2020           PA           Pennsylvania           State       NVSS
# 3  2020           CA             California           State       NVSS
# 4  2020           IA                   Iowa           State       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 1  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 2  Cardiovascular Diseases  Heart Disease Mortality       616.0
# 3  Cardiovascular Diseases  Heart Disease Mortality       229.5
# 4  Cardiovascular Diseases  Heart Disease Mortality       190.6
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 2  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 3  per 100,000 population                  Age-adjusted, 3-year Average Rate
# 4  per 100,000 population                  Age-adjusted, 3-year Average Rate
#
#    ... Data_Value_Footnote StratificationCategory1 Stratification1  \
# 0  ...   Insufficient Data                     Sex            Male
# 1  ...   Insufficient Data                     Sex          Female
# 2  ...                 NaN                     Sex            Male
# 3  ...                 NaN                     Sex         Overall
# 4  ...                 NaN                     Sex         Overall
#
#   StratificationCategory2 Stratification2 TopicID LocationID      Y_lat  \
# 0          Race/Ethnicity           Black      T2      60000 -14.301754
# 1          Race/Ethnicity           Asian      T2         38  47.447100
# 2          Race/Ethnicity           Black      T2         42  40.874900
# 3          Race/Ethnicity        Hispanic      T2          6  37.241400
# 4          Race/Ethnicity           Asian      T2         19  42.076000
#
#         X_lon                       Georeference
# 0 -170.719474  POINT (-170.7194738 -14.30175426)
# 1 -100.470000            POINT (-100.47 47.4471)
# 2  -77.802200           POINT (-77.8022 40.8749)
# 3 -119.601000           POINT (-119.601 37.2414)
# 4  -93.502200            POINT (-93.5022 42.076)
#
# [5 rows x 21 columns]

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78792 entries, 0 to 78791
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        78792 non-null  int64
#  1   LocationAbbr                78792 non-null  object
#  2   LocationDesc                78792 non-null  object
#  3   GeographicLevel             78792 non-null  object
#  4   DataSource                  78792 non-null  object
#  5   Class                       78792 non-null  object
#  6   Topic                       78792 non-null  object
#  7   Data_Value                  34430 non-null  float64
#  8   Data_Value_Unit             78792 non-null  object
#  9   Data_Value_Type             78792 non-null  object
#  10  Data_Value_Footnote_Symbol  44362 non-null  object
#  11  Data_Value_Footnote         44362 non-null  object
#  12  StratificationCategory1     78792 non-null  object
#  13  Stratification1             78792 non-null  object
#  14  StratificationCategory2     78792 non-null  object
#  15  Stratification2             78792 non-null  object
#  16  TopicID                     78792 non-null  object
#  17  LocationID                  78792 non-null  int64
#  18  Y_lat                       78768 non-null  float64
#  19  X_lon                       78768 non-null  float64
#  20  Georeference                78768 non-null  object
# dtypes: float64(3), int64(2), object(16)
# memory usage: 12.6+ MB

# %%
heart_df.isnull().sum()
# Out:
# Year                              0
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    44362
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    34430
# Data_Value_Footnote           34430
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                            24
# X_lon                            24
# Georeference                     24
# dtype: int64

# %%
heart_df.count()
# Out:
# Year                          78792
# LocationAbbr                  78792
# LocationDesc                  78792
# GeographicLevel               78792
# DataSource                    78792
# Class                         78792
# Topic                         78792
# Data_Value                    34430
# Data_Value_Unit               78792
# Data_Value_Type               78792
# Data_Value_Footnote_Symbol    44362
# Data_Value_Footnote           44362
# StratificationCategory1       78792
# Stratification1               78792
# StratificationCategory2       78792
# Stratification2               78792
# TopicID                       78792
# LocationID                    78792
# Y_lat                         78768
# X_lon                         78768
# Georeference                  78768
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Black', 'Asian', 'Hispanic', 'More than one race', 'White',
#        'Overall', 'American Indian or Alaska Native',
#        'Native Hawaiian or Other Pacific Islander'], dtype=object)

# %%
import seaborn as sns
sns.violinplot(x='Data_Value', y='Stratification2', data=heart_df)
# Out:
# <Axes: xlabel='Data_Value', ylabel='Stratification2'>
